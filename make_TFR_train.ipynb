# %%
import tensorflow as tf
import numpy as np
import os
import scipy.io.wavfile as wavfile
import math

# %%
def norm(inp):
    M = np.amax(np.absolute(inp))
    return inp/M

# %%
#### write ####

def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

# %%
save_path = './TFR'
out_file_name = 'DSEnet_DATA2_DEMAND_16bit_train.tfrecords'

target_dir = './DSEnet_train_DATA_1cm_16bit/LookD'
noisy_m1_dir = './DSEnet_train_DATA_1cm_16bit/MICR'
noisy_m2_dir = './DSEnet_train_DATA_1cm_16bit/MICL'

window = 16384
stride = int((0.5)*window)
print(stride)
# Out:
# 8192

# %%
out_filepath= os.path.join(save_path, out_file_name)
out_file = tf.python_io.TFRecordWriter(out_filepath)

# %%
target_ = os.listdir(target_dir)
noisy_m1_ = os.listdir(noisy_m1_dir)
noisy_m2_ = os.listdir(noisy_m2_dir) 
print(len(target_))
print(len(noisy_m1_))
print(len(noisy_m2_))
# Out:
# 11572
# 11572
# 11572

# %%
total_chunks = 0
for i in target_:
    fm, target = wavfile.read('./DSEnet_train_DATA_1cm_16bit/LookD/%s'%i)
    fm, noisy_m1 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICR/%s'%i)
    fm, noisy_m2 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICL/%s'%i)
  
    #### check data ####
    if fm != 16000:
        raise ValueError('Not 16kHz')
    if len(noisy_m2) != len(noisy_m1):
        raise ValueError('Clean and noise m1 are different')
    if len(target) != len(noisy_m2):
        raise ValueError('Clean and noise m2 are different')
    #### check data ####

    if int(len(target)/stride) == float(len(target))/stride:
        n_slice = int((len(target)-stride)/stride)
    else:
        n_slice = int(len(target)/stride)

    total_chunks = total_chunks + n_slice
print( 'Total chunks : ', total_chunks)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e6b9a8faff4d> in <module>
#       3     fm, target = wavfile.read('./DSEnet_train_DATA_1cm_16bit/LookD/%s'%i)
#       4     fm, noisy_m1 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICR/%s'%i)
# ----> 5     fm, noisy_m2 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICL/%s'%i)
#       6
#       7     #### check data ####
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     262                     raise ValueError("No fmt chunk before data")
#     263                 data = _read_data_chunk(fid, format_tag, channels, bit_depth,
# --> 264                                         is_big_endian, mmap)
#     265             elif chunk_id == b'LIST':
#     266                 # Someday this could be handled properly but for now skip it
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/wavfile.py in _read_data_chunk(fid, format_tag, channels, bit_depth, is_big_endian, mmap)
#     127             dtype += 'f%d' % bytes_per_sample
#     128     if not mmap:
# --> 129         data = numpy.frombuffer(fid.read(size), dtype=dtype)
#     130     else:
#     131         start = fid.tell()
#
# KeyboardInterrupt:

# %%
indx = 0
for i in target_:
    if indx % 100 == 0:
        print('{}/{}'.format(indx + 1, 100*(total_chunks//100)))

    fm, target = wavfile.read('./DSEnet_train_DATA_1cm_16bit/LookD/%s'%i)
    target = norm(target)
    fm, noisy_m1 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICR/%s'%i)
    fm, noisy_m2 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICL/%s'%i)
    #### slice data ####
    if int(len(target)/stride) == float(len(target))/stride:
        n_slice = int((len(target)-stride)/stride)
    else:
        n_slice = int(len(target)/stride)
    
    #print(n_slice)
    
    for j in range(n_slice):
        if j == n_slice-1:
            start_slice = j*stride
            n_pad = window-(len(target)-start_slice)
            end_slice = len(target)
            pad = np.zeros(n_pad)
            pad = np.array(pad, dtype=np.int16)
            
            target_sliced = target[start_slice:end_slice]
            target_sliced = np.append(target_sliced,pad)
            
            noisy_m1_sliced = noisy_m1[start_slice:end_slice]
            noisy_m1_sliced = np.append(noisy_m1_sliced,pad)
            
            noisy_m2_sliced = noisy_m2[start_slice:end_slice]
            noisy_m2_sliced = np.append(noisy_m2_sliced,pad)

            target_sliced = target_sliced.tostring()
            noisy_m1_sliced = noisy_m1_sliced.tostring()
            noisy_m2_sliced = noisy_m2_sliced.tostring()
        else:
            start_slice = j*stride
            end_slice = window + j*stride

            target_sliced = target[start_slice:end_slice]
            noisy_m1_sliced = noisy_m1[start_slice:end_slice]
            noisy_m2_sliced = noisy_m2[start_slice:end_slice]

            target_sliced = target_sliced.tostring()
            noisy_m1_sliced = noisy_m1_sliced.tostring()
            noisy_m2_sliced = noisy_m2_sliced.tostring()
      #### slice data ####
        if( indx < 100*(total_chunks//100)):
            example = tf.train.Example(features = tf.train.Features(feature={
                'target_raw' : _bytes_feature(target_sliced),
                'noisy_m1_raw' : _bytes_feature(noisy_m1_sliced),
                'noisy_m2_raw' : _bytes_feature(noisy_m2_sliced)}))
            out_file.write(example.SerializeToString())
            indx = indx + 1
        
        

out_file.close()
print('indx : ',indx,'DONE')
# Out:
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# 1/11572
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-214b0fbfdf5b> in <module>
#       7     target = norm(target)
#       8     fm, noisy_m1 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICR/%s'%i)
# ----> 9     fm, noisy_m2 = wavfile.read('./DSEnet_train_DATA_1cm_16bit/MICL/%s'%i)
#      10     #### slice data ####
#      11     if int(len(target)/stride) == float(len(target))/stride:
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     231         mmap = False
#     232     else:
# --> 233         fid = open(filename, 'rb')
#     234
#     235     try:
#
# KeyboardInterrupt:

# %%
# Out:
# 1200
